# %% [markdown]
# # API

# %%
from src.repositories.embrapa_api import EmbrapaAPI
from src.models.enum_embrapa_api import EnumEmbrapaAPI
import configparser
config = configparser.ConfigParser()
config.read('LOCAL')
ebp = EmbrapaAPI(config['USER']['USERNAME'],config['USER']['PASSWORD'])

# %%
ebp.get_embrapa_data(EnumEmbrapaAPI.PRODUCAO, year_from=2023, year_to=2023)
# Out:
# {'success': True,
#  'data': [{'product': 'tinto',
#    'liters': 139320884.0,
#    'group': 'vinho_de_mesa',
#    'year': 2023},
#   {'product': 'branco',
#    'liters': 27910299.0,
#    'group': 'vinho_de_mesa',
#    'year': 2023},
#   {'product': 'rosado',
#    'liters': 2531246.0,
#    'group': 'vinho_de_mesa',
#    'year': 2023},
#   {'product': 'tinto',
#    'liters': 23615783.0,
#    'group': 'vinho_fino_de_mesa_vinifera',
#    'year': 2023},
#   {'product': 'branco',
#    'liters': 20693437.0,
#    'group': 'vinho_fino_de_mesa_vinifera',
#    'year': 2023},
#   {'product': 'rosado',
#    'liters': 1959336.0,
#    'group': 'vinho_fino_de_mesa_vinifera',
#    'year': 2023},
#   {'product': 'suco_de_uva_integral',
#    'liters': 38122173.0,
#    'group': 'suco',
#    'year': 2023},
#   {'product': 'suco_de_uva_concentrado',
#    'liters': 28216760.0,
#    'group': 'suco',
#    'year': 2023},
#   {'product': 'suco_de_uva_adocado',
#    'liters': 94587.0,
#    'group': 'suco',
#    'year': 2023},
#   {'product': 'suco_de_uva_organico',
#    'liters': 611718.0,
#    'group': 'suco',
#    'year': 2023},
#   {'product': 'suco_de_uva_reconstituido',
#    'liters': 0.0,
#    'group': 'suco',
#    'year': 2023},
#   {'product': 'espumante',
#    'liters': 65525.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'espumante_moscatel',
#    'liters': 14744.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'base_espumante',
#    'liters': 0.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'base_espumante_moscatel',
#    'liters': 6734590.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'base_champenoise_champanha',
#    'liters': 1552243.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'base_charmat_champanha',
#    'liters': 5418118.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'bebida_de_uva',
#    'liters': 1627.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'polpa_de_uva',
#    'liters': 1388251.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'mosto_simples',
#    'liters': 157848983.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'mosto_concentrado',
#    'liters': 0.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'mosto_de_uva_com_bagaco',
#    'liters': 7784.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'mosto_dessulfitado',
#    'liters': 0.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'mistelas', 'liters': 600.0, 'group': 'derivados', 'year': 2023},
#   {'product': 'nectar_de_uva',
#    'liters': 70976.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'licorosos', 'liters': 0.0, 'group': 'derivados', 'year': 2023},
#   {'product': 'compostos', 'liters': 0.0, 'group': 'derivados', 'year': 2023},
#   {'product': 'jeropiga',
#    'liters': 4500.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'filtrado', 'liters': 0.0, 'group': 'derivados', 'year': 2023},
#   {'product': 'frisante', 'liters': 0.0, 'group': 'derivados', 'year': 2023},
#   {'product': 'vinho_leve', 'liters': 0.0, 'group': 'derivados', 'year': 2023},
#   {'product': 'vinho_licoroso',
#    'liters': 73600.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'brandy', 'liters': 450.0, 'group': 'derivados', 'year': 2023},
#   {'product': 'destilado', 'liters': 0.0, 'group': 'derivados', 'year': 2023},
#   {'product': 'bagaceira', 'liters': 0.0, 'group': 'derivados', 'year': 2023},
#   {'product': 'licor_de_bagaceira',
#    'liters': 0.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'vinagre', 'liters': 9000.0, 'group': 'derivados', 'year': 2023},
#   {'product': 'borra_liquida',
#    'liters': 758140.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'borra_seca',
#    'liters': 17200.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'vinho_composto',
#    'liters': 0.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'pisco', 'liters': 0.0, 'group': 'derivados', 'year': 2023},
#   {'product': 'vinho_organico',
#    'liters': 94150.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'espumante_organico',
#    'liters': 1365.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'destilado_alcoolico_simples_de_bagaceira',
#    'liters': 0.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'vinho_acidificado',
#    'liters': 2500.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'mosto_parcialmente_fermentado',
#    'liters': 0.0,
#    'group': 'derivados',
#    'year': 2023},
#   {'product': 'outros_derivados',
#    'liters': 652301.0,
#    'group': 'derivados',
#    'year': 2023}]}
